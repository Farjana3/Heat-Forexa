# %% [markdown]
# # 04. Modeling, Evaluation & Summer Forecasting
#
# Chronological time-based split, Baseline vs XGBoost vs SARIMAX evaluation, and June-July-August forecasts.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))
sys.path.insert(0, os.path.abspath('.'))

import pandas as pd
import matplotlib.pyplot as plt
from src.analysis.modeling import run_modeling_pipeline

# %%
# 1. Load Features
df_feat = pd.read_csv('data/processed/features.csv')
print(f'Features loaded: {df_feat.shape[0]:,} rows')
# Out:
# Features loaded: 316,566 rows

# %%
# 2. Execute Modeling Pipeline (Train/Val/Test Split & Benchmarking)
results = run_modeling_pipeline(df_feat, output_dir='output/result', fig_dir='output/figure')
print('=== MODEL COMPARISON RESULTS ===')
print(results['model_comparison'].to_string(index=False))
# Out:
# E:\project\src\analysis\modeling.py:145: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=importance_df.head(15), x='Importance', y='Feature', palette='crest')
# E:\project\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\project\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# === MODEL COMPARISON RESULTS ===
#                   Model  Val_MAE  Val_RMSE  Val_R2  Test_MAE  Test_RMSE  Test_R2
#    Persistence Baseline   0.5108    0.7179  0.4896    0.5695     0.7624   0.1340
#  XGBoost (Delta-Target)   0.5036    0.6894  0.5293    0.6171     0.7875   0.0762
# ARMAX (Delta Daily Agg)   0.5126    0.7039  0.3611    0.5545     0.7602  -0.0724

# %%
# 3. Top Feature Importances (XGBoost)
print('\n=== TOP 10 FEATURE IMPORTANCES ===')
print(results['feature_importance'].head(10).to_string(index=False))
# Out:
# === TOP 10 FEATURE IMPORTANCES ===
#                   Feature  Importance
#        wind_gusts_10m_max    0.146875
#        temperature_2m_min    0.089149
# apparent_temperature_mean    0.083867
#         sunshine_duration    0.068578
#  apparent_temperature_max    0.056793
#        wind_speed_10m_max    0.056670
#       temperature_2m_mean    0.049372
#                   dom_cos    0.049306
#             temp_2m_range    0.048315
#       apparent_temp_range    0.043345

# %%
# 4. Summer 2026 Forecasting Summary (June, July, August)
print('\n=== SUMMER 2026 FORECAST SUMMARY ===')
forecast_df = results['summer_forecast']
print(forecast_df.groupby('month')['projected_daily_mean_temperature'].agg(['count', 'mean', 'min', 'max']))
# Out:
# === SUMMER 2026 FORECAST SUMMARY ===
#         count       mean        min        max
# month
# August     31  29.868000  29.868000  29.868000
# July       29  29.861296  28.227921  30.933648
# June       23  29.962062  28.487050  30.786679
